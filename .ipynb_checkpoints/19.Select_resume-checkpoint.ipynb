# %%
from gensim.models import Word2Vec
import gensim
import jieba
import pymongo
import json

# %%
model = gensim.models.Word2Vec.load('resume_model.model')

# %%
def jieba_cut(data, stop_words): # 定義使用結巴程式
    '''
    input:
        data : string
        stop_words: list of stopwords
    output:
        lst_seg : list of words after jieba
    '''

    # 使用結巴斷詞，產生 list of words
    seg_result = jieba.cut(data, cut_all=False)

    # 篩選斷詞，去掉單一中文字
    lst_seg = []

    for i in list(seg_result):
        i = i.strip()
        if len(i) < 1:  # 排除空值
            continue
        elif isEnglish(i) == False and len(i) == 1:  # 排除單一中文字
            continue
        elif i.isdigit() == True:  # 排除數字
            continue
        elif i in stop_words:  # 排除stopwords
            continue

        else:
            lst_seg.append(i)

    return lst_seg

# %%
def create_joblist_for_similar(job_list,model):
    user_list = []
    for word in job_list:
        if word in model.wv.vocab.keys():
            user_list.append(word)
        else:
            pass
    return user_list

# %%
def mongo_connect_build(db_name, col_name):
    
    global mycol
    client = pymongo.MongoClient("mongodb://192.168.1.25:27017/") 

    db = client[db_name] # 選擇使用的db,不存在則會在資料輸入時自動建立
    mycol = db[col_name] # 選擇collection,不存在則會在資料輸入時自動建立

def data_find():
    # 尋找多筆資料
    return mycol.find({},{'_id':0})

# %%
def open_json_file(CACHE_FNAME):
    try:
        cache_file = open(CACHE_FNAME, 'r', encoding='utf-8-sig')
        cache_contents = cache_file.read()
        CACHE_DICTION = json.loads(cache_contents, encoding='utf-8-sig')
        cache_file.close()
        return CACHE_DICTION

    except:
        CACHE_DICTION = {}
        return CACHE_DICTION

# %%
'''
丟入要匹配的user_list,
用model.n_similarity相似度匹配,
用user_list配對每一筆cv_list,求出相似度建立字典
'''
def job_map_cv(cv_dict,model,user_list):
    rate_dict = {}
    for k,v in zip(cv_dict.keys(),cv_prob.values()):    
        rate = model.n_similarity(v,user_list)
        rate_dict[k] = rate
        rate_sort = sorted(rate_dict.items(), key=lambda x:x[1],reverse=True)
        rate_list = list(rate_sort)
    return rate_list

# %%
def resume_select_url(rate_list):
    for i in range(0,10):
        print('https://www.cakeresume.com/' + str(rate_list[i][0]))
        print('============================================================')

# %%
cv_data = open_json_file('resume_for_similar.json')

# %%
cv_data.values()
# Out:
# dict_values([['analysis', 'aoi', 'app', 'application', 'azure', 'bootstrap', 'cc', 'codeigniter', 'communication', 'computing', 'cpr', 'css', 'data', 'django', 'education', 'es', 'ex', 'experience', 'gcp', 'gept', 'hadoop', 'html', 'ibm', 'ic', 'inventor', 'iot', 'javascript', 'jquery', 'js', 'lab', 'microsoft', 'mining', 'ml', 'mobile', 'mysql', 'node', 'php', 'project', 'python', 'sas', 'school', 'server', 'skills', 'spark', 'sql', 'streaming', 'toeic', 'vue', 'web', '交通', '人工智慧', '企業', '作品', '信託', '健身', '偵測', '優化', '元件', '兒童', '全國', '全球', '公會', '兼任', '分析', '前後端', '前端', '創新', '功能', '助人', '助教', '助理', '半導體', '協助', '協調', '台灣', '同業', '吧台', '品質', '商業', '國家', '國際', '外包', '大地', '大學', '大數據', '學校', '學生', '客戶', '客服', '客製化', '家教', '實習', '實習生', '實驗', '實驗室', '封裝', '專案', '專業', '專題', '工具', '工業', '工研院', '工程', '市場', '常識', '建構', '影片', '後端', '微軟', '志工', '技巧', '技術', '指導', '挑戰', '排版', '排程', '排解', '控制', '提升', '撰寫', '支援', '救生', '教學', '教授', '教材', '教育', '教育部', '整理', '數據', '文章', '新創', '晶圓', '智慧', '智能', '服務', '期貨', '材料', '校務', '框架', '業務', '模型', '模板', '模組', '機器學習', '機械', '檢測', '流程', '深度學習', '游泳池', '演算法', '無線', '營隊', '物聯網', '生成', '產品', '產學', '疑難雜症', '發展', '研發', '研究', '研究所', '社團', '社會', '科學', '科技', '程式', '競賽', '管理', '簡介', '精進', '系統', '系統性', '組裝', '結合', '結構', '統計', '維護', '網站', '網路', '網頁', '聯絡', '職業', '英文', '蒐集', '製程', '製造', '解決', '計畫', '計算', '計算機', '訊號', '設備', '設計', '認證', '語言', '語音', '課堂', '課程', '課輔', '講師', '證券', '證券商', '證照', '議題', '財務', '資料', '資料庫', '資訊', '軟硬體', '輔導', '辨識', '進入', '遊戲', '運動', '道德', '配對', '醫學', '金融', '開發', '障礙', '電機', '電路', '預測', '領袖', '體適能', '高級'], ['ad', 'analysis', 'app', 'apply', 'area', 'ba', 'background', 'business', 'ca', 'capability', 'career', 'chinese', 'code', 'communication', 'computer', 'cross', 'culture', 'director', 'education', 'effect', 'engineer', 'english', 'exchange', 'experience', 'experiences', 'foreign', 'group', 'guide', 'highly', 'ielts', 'include', 'industry', 'ing', 'international', 'knowledge', 'language', 'leading', 'learning', 'life', 'major', 'management', 'manager', 'mandarin', 'mba', 'medical', 'ng', 'point', 'pop', 'portfolio', 'professional', 'research', 'sales', 'school', 'skill', 'skills', 'strategies', 'teaching', 'tesol', 'toefl', 'uc', 'uk', 'value', 'work', '主修', '人資', '人類', '介紹', '代辦', '企業', '作業', '供應', '保險', '免疫', '全額', '兼任', '分析', '分校', '副理', '創立', '包裝', '化學', '升學', '協助', '口譯', '同業', '告訴', '商學', '國外', '國家', '國際', '地圖', '基礎', '外語', '大學', '委員', '學校', '學生', '室內', '家教', '家長', '審核', '寫作', '專案', '專業', '專長', '導師', '工具', '工廠', '工程', '常見', '建築', '引導', '影視', '成果', '戲劇', '手續', '技巧', '拓展', '指導', '探索', '接待', '接洽', '推廣', '政治', '教學', '教材', '教育', '整理', '數據', '文化', '旅遊', '日本', '會員', '會計', '服務', '業務', '業界', '概論', '標準', '機械', '機構', '機電', '檔案', '權益', '歷史', '歷練', '治療', '流程', '流行', '海報', '海外', '消防', '準備', '溝通', '溫度', '潤飾', '燈光', '牙醫', '物流', '物理', '理工', '理論', '生命', '生物', '產業', '申請', '留學', '研發', '研究', '研究所', '碩士', '科學', '科技', '程序', '競爭', '策劃', '策略', '管理', '管道', '簽證', '粉絲', '系統', '組織', '結合', '美國', '義大利', '翻譯', '考試', '職務', '職涯', '背景', '舉行', '舉辦', '航太', '英文', '英語', '菁英', '藝術', '行銷', '衛生', '補習班', '規劃', '討論', '設計', '評鑑', '語言', '課程', '論文', '諮詢', '講座', '證書', '證照', '譯者', '護理', '財務', '資訊', '趨勢', '輔導', '辦理', '追蹤', '進階', '過程', '道路', '醫務', '醫學', '醫療', '醫院', '重要', '鑑識', '關心', '電影', '電機', '電腦', '音樂', '顧問', '飯店'], ['ad', 'ar', 'edm', 'facebook', 'fb', 'ga', 'google', 'ig', 'illustrator', 'kol', 'kpi', 'live', 'microsoft', 'office', 'personal', 'photoshop', 'premiere', 'pro', 'spark', 'web', 'windows', 'youtube', '上市', '主修', '互動', '介紹', '企劃', '企業', '傳播', '傳遞', '分析', '刊登', '創意', '協助', '印刷', '反應', '台灣', '品牌', '國外', '報告', '多媒體', '大學', '娛樂', '媒體', '學歷', '客戶', '宣傳', '實習生', '專案', '專業', '專科', '小編', '展現', '市場', '平台', '平面', '廠商', '廣告', '影片', '後台', '微軟', '徵才', '成效', '房屋', '才能', '打破', '打造', '技能', '投放', '拍攝', '挑戰', '接洽', '提升', '撰寫', '操作', '支援', '改變', '效益', '數位', '數據', '文案', '族群', '最大化', '案例', '模式', '機動性', '洽談', '消費', '溝通', '營運', '狀況', '現場', '皮膚', '直銷', '社團', '社群', '競品', '管理', '粉絲', '粉絲團', '素材', '經濟部', '經營', '網友', '網站', '線上', '線下', '編輯', '美術', '自媒體 ...
